# %%
import pandas as pd

# %%
engadget_df = pd.read_csv("crawler_data/Engadget_iphone13_Data20220622.csv")
#mobile01_df = pd.read_csv("crawler_data/")
ppt_df = pd.read_csv("crawler_data/PPT_iphone13_Data20220606.csv")
dcfever_df = pd.read_csv("crawler_data/DCfever_iphone13_Data20220623.csv")

# %%
training_content = []
for c in engadget_df.loc[:,"Content"]:
    training_content.append(c)
for c in ppt_df.loc[:,"Content"]:
    training_content.append(c)
for c in dcfever_df.loc[:,"Content"]:
    training_content.append(c)

training_content
# Out:
# ["['Engadget 編輯團隊致力為你蒐羅優質產品及優惠價格，文章內部份連結商戶與 Engadget 有合作關係，定價及供應量有機會更改，一切以商戶最新資料為凖。', '隨著科技進步，處理不同事情幾乎都在筆電、手機等裝置中進行，不論是輸入密碼或是跟別人聊天，在人口稠密的地方總覺得很容易被人看見，四下無人又會擔心被駭客入侵，導致私隱洩露。這時候防窺保護貼、鏡頭保護蓋都能派上用場。', '防窺保護貼可以讓一定視角範圍外的旁人無法窺看熒幕內容，左右兩邊看到的只是漆黑一片，不用擔心密碼、訊息等暴露在窺視的目光中。', '撥動式的鏡頭保護蓋可以覆蓋手機、平板或筆電的前置鏡頭，即使不小心被駭客入侵，也能夠有效防止私隱洩露。當需要使用前置鏡頭時，只需輕輕一推即可，日常使用也不會阻礙使用 Face ID 解鎖。', '']",
#  "['MagSafe 版 Mobile Filmmaker Cage 適用於 iPhone 12 和 13 系列，更舊的 iPhone 機種就需要配合 MagSafe 保護套才能使用。它的售價是 US$99，目前已上架 Moment 官網。']",
#  "['Engadget 編輯團隊致力為你蒐羅優質產品及優惠價格，文章內部份連結商戶與 Engadget 有合作關係，定價及供應量有機會更改，一切以商戶最新資料為凖。', '今天晚上 9 時，松嶺綠 iPhone 13、13 Pro 便會開始接受預訂，有興趣的用家可以從下方的連結前往官網下單。', '但亦有不少用家早就擁有 iPhone 13，如果只為了配色而購買一部同型號的新手機，相信有不少用家也會望而卻步。Casetify 上就有著不少綠色的手機殼，可以帶給手機提供卓越的防護性能，包括防摔以及能夠消除 99％ 細菌的 Defensify 抗菌塗層，美觀和實用兼備。', '']",
# ...

# %%
len(str(training_content))
# Out:
# 144534

# %%
with open("training_data/training_content.txt", "w") as output:
    output.write(str(training_content))
