# %%
with open('NTUSD_positive_unicode.txt', encoding='utf-16', mode='r') as f:
    positive_words = []
    for l in f:
        positive_words.append(l.strip())
positive_words
# Out:
# ['一帆風順',
#  '一帆風順的',
#  '一流',
#  '一致',
#  '一致的',
#  '了不起',
#  '了不起的',
#  '了解',
#  '人性',
#  '人性的',
#  '人格高尚',
#  '人格高尚的',
#  '人情',
#  '人情味',
#  '入神',
#  '入神的',
#  '入迷',
#  '入迷的',
#  '上好',
#  '上好的',
#  '上等',
#  '上等的',
#  '口頭通過',
#  '大方',
#  '大方的',
#  '大無畏',
#  '大無畏的',
#  '大量的',
#  '大膽',
#  '大膽的',
#  '小天使',
#  '小心',
#  '小心的',
#  '小心謹慎',
#  '小心謹慎的',
#  '工整',
#  '工整的',
#  '才氣',
#  '才能',
#  '才智',
#  '才幹',
#  '才藝',
#  '不凡',
#  '不凡的',
#  '不凡的人',
#  '不可名狀',
#  '不可名狀的',
#  '不可否認',
#  '不可否認的',
#  '不可侵犯',
#  '不可侵犯的',
#  '不可思議',
#  '不可思議的',
#  '不任性',
#  '不任性的',
#  '不成為問題',
#  '不成為問題的',
#  '不自私',
#  '不自私的',
#  '不含糊',
#  '不含糊的',
#  '不受約束',
#  '不受約束的',
#  '不屈不撓',
#  '不屈不撓的',
#  '不屈服',
#  '不屈服的',
#  '不拘泥',
#  '不拘泥的',
#  '不迫',
#  '不偏不倚',
#  '不偏不倚地',
#  '不偏不倚的',
#  '不動搖',
#  '不動搖的',
#  '不猶豫',
#  '不猶豫的',
#  '不慌忙',
#  '不慌忙的',
#  '不會弄錯',
#  '不會弄錯的',
#  '不會受傷害',
#  '不會受傷害的',
#  '不懈',
#  '中和',
#  '中肯',
#  '中肯的',
#  '井然有序',
#  '井然有序的',
#  '互助',
#  '互助的',
#  '互相密合著',
#  '互相密合著的',
#  '仁慈',
#  '仁慈的',
#  '允諾',
#  '內行',
#  '內行的',
#  '公平',
#  '公平地',
#  '公平的',
#  '公正',
#  '公正地',
#  '公正的',
#  '公開',
#  '公開的',
#  '分寸',
#  '切實',
#  '切實的',
#  '切題',
#  '切題的',
#  '勻稱',
#  '勻稱的',
#  '升起',
#  '友好',
#  '友好的',
#  '友善',
#  '友善的',
#  '友愛',
#  '友愛的',
#  '友誼',
#  '及格',
#  '天才',
#  '天才人物',
#  '天使',
#  '天使的',
#  '天使般的人',
#  '天真',
#  '天真的',
#  '天真無邪',
#  '天堂',
#  '天然',
#  '天然的',
#  '天資',
#  '天賦',
#  '引人注目',
#  '引人注目的',
#  '引人讚美',
#  '引人讚美的人',
#  '引以為榮',
#  '引以為榮的事物',
#  '心甘情願',
#  '心甘情願的',
#  '心情愉快',
#  '心情愉快的',
#  '心情舒暢',
#  '心情舒暢的',
#  '心愛',
#  '心愛的',
#  '心滿意足',
#  '心滿意足地注視',
#  '心醉',
#  '心醉神迷',
#  '手藝',
#  '支援',
#  '文雅',
#  '文雅的',
#  '方便',
#  '方便的',
#  '比較好',
#  '主動',
#  '主動的',
#  '令人高興',
#  '令人高興的',
#  '令人喜悅',
#  '令人喜悅的',
#  '令人愉快',
#  '令人愉快的',
#  '令人欽佩',
#  '令人欽佩的',
#  '令人滿意',
#  '令人滿意地',
#  '令人滿意的',
#  '令人難忘',
#  '令人難忘的',
#  '令人驚奇',
#  '令人驚奇的',
#  '充分',
#  '充份',
#  '充份的',
#  '充沛',
#  '充足',
#  '充足的',
#  '充裕',
#  '充滿深情',
#  '充滿深情的',
#  '出名',
#  '出名的',
#  '出色',
#  '出色的',
#  '出神',
#  '出神的',
#  '出眾',
#  '出眾的',
#  '加薪',
#  '功績',
#  '去除',
#  '可了解',
#  '可了解的',
#  '可口',
#  '可口的',
#  '可以接受',
#  '可以接受的',
#  '可用',
#  '可用的',
#  '可行',
#  '可行的',
#  '可忍受',
#  '可忍受的',
#  '可取',
#  '可取的',
#  '可信',
#  '可信任',
#  '可信任的',
#  '可信的',
#  '可信賴',
#  '可信賴性',
#  '可信賴的',
#  '可理解',
#  '可理解的',
#  '可喜',
#  '可喜的',
#  '可尊敬',
#  '可尊敬的',
#  '可欽佩',
#  '可欽佩的',
#  '可貴',
#  '可貴的',
#  '可愛',
#  '可愛地',
#  '可愛的',
#  '可敬',
#  '可敬的',
#  '可敬重',
#  '可敬重的',
#  '可經營',
#  '可經營的',
#  '可實行',
#  '可實行的',
#  '可稱讚',
#  '可稱讚的',
#  '可靠',
#  '可靠性',
#  '可靠的',
#  '可靠程度',
#  '可親',
#  '可攜帶',
#  '可攜帶的',
#  '古典',
#  '古典的',
#  '古雅',
#  '古雅的',
#  '叮囑',
#  '巨大',
#  '巨大的',
#  '巧妙',
#  '巧妙的',
#  '平安',
#  '平安的',
#  '平坦',
#  '平坦的',
#  '平息',
#  '平等',
#  '平整',
#  '平衡',
#  '平靜',
#  '平靜的',
#  '平穩',
#  '平穩的',
#  '必要',
#  '打趣',
#  '本著良心',
#  '本著良心的',
#  '未被污染',
#  '未被污染的',
#  '正大',
#  '正式',
#  '正式批准',
#  '正式的',
#  '正直',
#  '正直的',
#  '正派',
#  '正派的',
#  '正面',
#  '正面地',
#  '正常',
#  '正常的',
#  '正統',
#  '正規',
#  '正規的',
#  '正當',
#  '正當的',
#  '正義',
#  '正義的',
#  '正道',
#  '正確',
#  '正確地',
#  '正確性',
#  '正確的',
#  '永恆',
#  '永恆的',
#  '甘願',
#  '甘願的',
#  '生育',
#  '生效',
#  '生效的',
#  '生氣勃勃',
#  '生氣勃勃地',
#  '生動',
#  '生動的',
#  '生產',
#  '生產多',
#  '生產多的',
#  '用功',
#  '由衷',
#  '由衷的高興',
#  '目眩',
#  '伊甸園',
#  '休息',
#  '光芒',
#  '光芒四射',
#  '光芒四射的',
#  '光明',
#  '光明的',
#  '光亮',
#  '光亮的',
#  '光彩',
#  '光滑',
#  '光滑的',
#  '光榮',
#  '光榮的',
#  '光輝',
#  '光輝的',
#  '光澤',
#  '先見之明',
#  '全力',
#  '全力的',
#  '全面',
#  '全面的',
#  '全神貫注',
#  '全神貫注的',
#  '吉利',
#  '吉利的',
#  '吉祥',
#  '吉祥的',
#  '同情',
#  '同情心',
#  '同意',
#  '同意給予',
#  '同感',
#  '名聲',
#  '名譽',
#  '合乎',
#  '合乎情理',
#  '合乎情理的',
#  '合乎衛生',
#  '合乎衛生的',
#  '合乎邏輯',
#  '合乎邏輯的',
#  '合作',
#  '合作的',
#  '合宜',
#  '合法',
#  '合法性',
#  '合法的',
#  '合格',
#  '合理',
#  '合理的',
#  '合意',
#  '合意的',
#  '合群',
#  '合適',
#  '合適地',
#  '合適的',
#  '吃苦',
#  '吃苦耐勞',
#  '在乎',
#  '在意',
#  '在贊成方面',
#  '多才多藝',
#  '多才多藝的',
#  '多產',
#  '多產的',
#  '多智',
#  '多智的',
#  '多趣',
#  '多趣的',
#  '好天氣',
#  '好吃',
#  '好吃的',
#  '好事',
#  '好奇',
#  '好奇的',
#  '好客',
#  '好客的',
#  '好笑',
#  '好笑的',
#  '好追根究底',
#  '好追根究底的',
#  '好意',
#  '好意地',
#  '好運',
#  '好運的',
#  '好辦法',
#  '如畫',
#  '如畫的',
#  '守法',
#  '守法的',
#  '安全',
#  '安全的',
#  '安定',
#  '安逸',
#  '安逸的',
#  '安詳',
#  '安詳的',
#  '安寧',
#  '安寧的',
#  '安慰',
#  '安適',
#  '安適的',
#  '安靜',
#  '安靜的',
#  '安穩',
#  '成功',
#  '成功的',
#  '成長',
#  '成為',
#  '成就',
#  '成熟',
#  '成熟的',
#  '收穫',
#  '有力',
#  '有力的',
#  '有才氣',
#  '有才氣的',
#  '有才能',
#  '有才能的',
#  '有才智',
#  '有才智的',
#  '有才幹',
#  '有才幹的',
#  '有才幹的人',
#  '有分寸',
#  '有分寸的',
#  '有天才的',
#  '有天資',
#  '有天資的',
#  '有天賦',
#  '有天賦的',
#  '有功績',
#  '有功績的',
#  '有用',
#  '有用的',
#  '有目的',
#  '有目的的',
#  '有光澤',
#  '有光澤的',
#  '有先見之明',
#  '有先見之明的',
#  '有同情心',
#  '有同情心的',
#  '有名',
#  '有名的',
#  '有判斷力',
#  '有判斷力的',
#  '有利',
#  '有利的',
#  '有利益',
#  '有利益的',
#  '有利條件',
#  '有利潤',
#  '有利潤的',
#  '有助',
#  '有助的',
#  '有助益',
#  '有助益的東西',
#  '有吸引力',
#  '有吸引力的',
#  '有含義',
#  '有含義的',
#  '有把握',
#  '有把握地',
#  '有把握的',
#  '有決心',
#  '有決心的',
#  '有知覺',
#  '有知覺的',
#  '有信心',
#  '有信心的',
#  '有前途',
#  '有品格',
#  '有品格的',
#  '有威嚴',
#  '有威嚴的',
#  '有思想',
#  '有思想性',
#  '有思想性的',
#  '有指望',
#  '有耐性',
#  '有耐性的',
#  '有效',
#  '有效性',
#  '有效的',
#  '有效率',
#  '有效率的',
#  '有特色',
#  '有特色的',
#  '有益',
#  '有益於健康',
#  '有益於健康的',
#  '有益的',
#  '有益健康',
#  '有益健康的',
#  '有秩序',
#  '有能力',
#  '有能力的',
#  '有財產',
#  '有財產的',
#  '有教育意義',
#  '有教育意義的',
#  '有理',
#  '有規矩',
#  '有規範',
#  '有規範的',
#  '有責任',
#  '有責任心',
#  '有責任心的',
#  '有責任的',
#  '有創造力',
#  '有創造力的',
#  '有智慧',
#  '有智慧的',
#  '有貴族氣派',
#  '有貴族氣派的',
#  '有進取精神',
#  '有進取精神的',
#  '有雅量',
#  '有雅量的',
#  '有勢力',
#  '有勢力的',
#  '有幹勁',
#  '有幹勁的',
#  '有意義',
#  '有意義的',
#  '有感覺',
#  '有感覺的',
#  '有愛心',
#  '有愛心的',
#  '有愛國心',
#  '有愛國心的',
#  '有節制',
#  '有節制的',
#  '有義務的',
#  '有道德',
#  '有道德的',
#  '有精神',
#  '有說服力',
#  '有說服力的',
#  '有遠見',
#  '有遠見的',
#  '有價值',
#  '有價值的',
#  '有價值的人',
#  '有樂趣',
#  '有樂趣的',
#  '有確實根據',
#  '有確實根據的',
#  '有趣',
#  '有趣的',
#  '有魅力',
#  '有魅力的',
#  '有錢',
#  '有錢的',
#  '有頭腦',
#  '有頭腦的',
#  '有幫手',
#  '有幫手的',
#  '有幫助',
#  '有幫助的',
#  '有幫助的人',
#  '有膽量',
#  '有膽量的',
#  '有禮',
#  '有禮貌',
#  '有禮貌的',
#  '有禮貌的行為',
#  '有魔力',
#  '有魔力的',
#  '有權',
#  '有權力',
#  '有權力的',
#  '有權益',
#  '有權益的',
#  '有權能',
#  '有權能的',
#  '老實',
#  '老實的',
#  '老練',
#  '老練的',
#  '考慮',
#  '自主',
#  '自由',
#  '自由的',
#  '自白',
#  '自立',
#  '自在',
#  '自信',
#  '自信地',
#  '自動',
#  '自動的',
#  '自尊',
#  '自然',
#  '自然的',
#  '自豪',
#  '自豪的',
#  '自願',
#  '至上',
#  '至上的',
#  '至高',
#  '至高的',
#  '至善',
#  '至善的',
#  '行善',
#  '行善的',
#  '似天使',
#  '似天使的',
#  '似乎有理',
#  '作為獎品',
#  '作為獎品的',
#  '伶俐',
#  '伶俐的',
#  '克制',
#  '免除',
#  '免除的',
#  '免費',
#  '免費的',
#  '冷靜',
#  '冷靜的',
#  '別致',
#  '別致的',
#  '判斷力',
#  '利益',
#  '利潤',
#  '助手',
#  '助長',
#  '助益',
#  '努力',
#  '努力的',
#  '努力解決',
#  '吸引',
#  '吸引人',
#  '吸引人的',
#  '吸引人的事物',
#  '吸引力',
#  '均勻',
#  '均等',
#  '均衡',
#  '均衡的',
#  '壯麗',
#  '壯麗的',
#  '壯麗雄偉',
#  '壯麗雄偉的',
#  '壯觀',
#  '壯觀的',
#  '妙計',
#  '妥當',
#  '孝行',
#  '孝順',
#  '孝順的',
#  '完成',
#  '完成的',
#  '完美',
#  '完美的',
#  '完整',
#  '完整的',
#  '宏偉',
#  '宏偉的',
#  '希望',
#  '形影不離',
#  '形影不離的朋友',
#  '忘不了',
#  '忘不了的',
#  '志哀',
#  '志氣',
#  '忍耐',
#  '忍耐力',
#  '忍耐的',
#  '快活',
#  '快活的',
#  '快樂',
#  '快樂主義',
#  '快樂主義的',
#  '快樂主義者',
#  '快樂主義者的',
#  '快樂地',
#  '快樂的',
#  '快樂論',
#  '快樂論的',
#  '戒除',
#  '技巧',
#  '把握',
#  '批准',
#  '抒情',
#  '抒情的',
#  '改良',
#  '改革',
#  '改善',
#  '改進',
#  '攻讀',
#  '沈著',
#  '沈著的',
#  '決心',
#  '決定',
#  '決定性',
#  '決定性的',
#  '決斷',
#  '決斷力',
#  '沖勁',
#  '牢固',
#  '牢固的',
#  '牢靠',
#  '狂喜',
#  '狂喜的',
#  '狂熱',
#  '狂熱的',
#  '狂熱讚揚',
#  '狂歡',
#  '狂歡的',
#  '罕見',
#  '罕見的',
#  '良心',
#  '良心的',
#  '良好',
#  '良好的',
#  '良性',
#  '良性的',
#  '足夠',
#  '足夠的',
#  '足智多謀',
#  '迅速',
#  '迅速地',
#  '迅速的',
#  '防止',
#  '防水',
#  '防水的',
#  '防備',
#  '事跡',
#  '享有',
#  '享受',
#  '使人信服',
#  '使人信服的',
#  '使人首肯',
#  '使人首肯的',
#  '使人敬畏',
#  '使人敬畏的',
#  '使平坦',
#  '使平靜',
#  '使平靜下來',
#  '使用方便',
#  '使用方便的',
#  '使安靜',
#  '使免除',
#  '使固定',
#  '使相等',
#  '使涼快',
#  '使陶醉',
#  '使精細',
#  '使緩和',
#  '使醉心',
#  '供娛樂用',
#  '供娛樂用的',
#  '典雅',
#  '典雅的',
#  '刻苦',
#  '刻苦的',
#  '協力',
#  '協力的',
#  '協作',
#  '協助',
#  '協調',
#  '卓越',
#  '卓越的',
#  '取悅',
#  '受大眾歡迎',
#  '受鍾愛',
#  '受鍾愛的',
#  '受歡迎',
#  '受歡迎的',
#  '和平',
#  '和平的',
#  '和睦',
#  '和睦的',
#  '和諧',
#  '和諧的',
#  '和藹',
#  '和藹可親',
#  '和藹可親的',
#  '和藹的',
#  '周到',
#  '周到的',
#  '固守',
#  '固守的',
#  '固定',
#  '固定的',
#  '坦白',
#  '坦白的',
#  '坦直',
#  '坦直的',
#  '坦率',
#  '坦率的',
#  '奇妙',
#  '奇妙的',
#  '奇異',
#  '奇跡',
#  '奇跡的',
#  '宜人',
#  '宜人的',
#  '尚好',
#  '幸運',
#  '幸運地',
#  '幸運的',
#  '幸福',
#  '幸福的',
#  '征服',
#  '忠心',
#  '忠貞',
#  '忠貞的',
#  '忠誠',
#  '忠誠的',
#  '忠誠的行為',
#  '忠實',
#  '忠實的',
#  '承認',
#  '承諾',
#  '招待',
#  '招待周到',
#  '招待周到的',
#  '放下武器',
#  '放心',
#  '放心的',
#  '易控制',
#  '易控制的',
#  '易理解',
#  '易理解的',
#  '易管理',
#  '易管理的',
#  '易辦',
#  '易辦的',
#  '易懂',
#  '昌盛',
#  '昌盛的',
#  '明了',
#  '明白',
#  '明白的',
#  '明亮',
#  '明亮的',
#  '明亮照耀',
#  '明亮照耀的',
#  '明理',
#  '明理的',
#  '明晰',
#  '明晰的',
#  '明智',
#  '明智的',
#  '明智的行為',
#  '明確',
#  '明瞭',
#  '明瞭的',
#  '明顯',
#  '明顯的',
#  '服從',
#  '服從的',
#  '欣喜',
#  '欣然',
#  '欣然地',
#  '欣賞',
#  '注目',
#  '注重實際',
#  '注重實際的',
#  '注意',
#  '注意的',
#  '法定',
#  '法定的',
#  '法律',
#  '法律的',
#  '治療',
#  '物廉價美',
#  '物廉價美的',
#  '的確',
#  '的確地',
#  '直言不諱',
#  '直言不諱的',
#  '直率',
#  '直率的',
#  '直截了當',
#  '直覺',
#  '直覺的',
#  '知足',
#  '知性',
#  '知性的',
#  '知恩',
#  '知罪',
#  '知道',
#  '知覺',
#  '肥沃',
#  '肥沃的',
#  '肯定',
#  '肯定的',
#  '肯定詞',
#  '肯定語',
#  '肯順從',
#  '肯順從的',
#  '芳香',
#  '芳香的',
#  '芬芳',
#  '芬芳的',
#  '表示贊成',
#  '表示贊成的',
#  '表現突出',
#  '表現突出的',
#  '表揚',
#  '長處',
#  '非凡',
#  '非凡的',
#  '非常大方',
#  '非常大方的',
#  '非常合適',
#  '非常合適的',
#  '信心',
#  '信用',
#  '信任',
#  '信服',
#  '信實',
#  '信賴',
#  '便利',
#  '便利的',
#  '便宜',
#  '俠義',
#  '俠義的',
#  '保密',
#  '保證',
#  '保釋',
#  '保護',
#  '促成',
#  '促成的',
#  '促進',
#  '俘獲',
#  '冠軍',
#  '冠軍的',
#  '前進',
#  '勇氣',
#  '勇猛',
#  '勇敢',
#  '勇敢的',
#  '勇敢的行為',
#  '勇敢的事跡',
#  '厚道',
#  '厚道的',
#  '品行',
#  '品行端正',
#  '品行端正的',
#  '品味',
#  '品性端正',
#  '品性端正的',
#  '威嚴',
#  '威嚴的',
#  '客氣',
#  '客氣的',
#  '幽默',
#  '幽默感',
#  '建設',
#  '建設性',
#  '建設性的',
#  '很多',
#  '很多的',
#  '很好',
#  '很好地',
#  '很好的',
#  '很棒',
#  '很棒的',
#  '待人如友',
#  '思考',
#  '思想性',
#  '恰好',
#  '恰好的',
#  '恰當',
#  '恰當地',
#  '恰當的',
#  '恆久',
#  '恆久不變',
#  '恆心',
#  '持久',
#  '持久的',
#  '指望',
#  '施捨',
#  '施捨慷慨',
#  '施捨慷慨的',
#  '柔和',
#  '柔和的',
#  '柔軟',
#  ...]

# %%
# -*- coding: utf-8 -*-
from ckiptagger import WS, POS, NER

text = '傅達仁今將執行安樂死，卻突然爆出自己20年前遭緯來體育台封殺，他不懂自己哪裡得罪到電視台。'
ws = WS("./data")
pos = POS("./data")
ner = NER("./data")

ws_results = ws([text])
pos_results = pos(ws_results)
ner_results = ner(ws_results, pos_results)

print(ws_results)
print(pos_results)
for name in ner_results[0]:
    print(name)
# Out:
# 2022-04-24 18:04:28.528349: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-24 18:04:28.528379: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-24 18:04:28.635272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:29.007964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:33.080658: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-24 18:04:33.080696: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-24 18:04:33.190188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:33.458957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:37.090828: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-24 18:04:37.090853: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-04-24 18:04:37.185378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:37.452451: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:37.897006: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:38.866361: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-24 18:04:39.480801: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [['傅達仁', '今', '將', '執行', '安樂死', '，', '卻', '突然', '爆出', '自己', '20', '年', '前', '遭', '緯來', '體育台', '封殺', '，', '他', '不', '懂', '自己', '哪裡', '得罪到', '電視台', '。']]
# [['Nb', 'Nd', 'D', 'VC', 'Na', 'COMMACATEGORY', 'D', 'D', 'VJ', 'Nh', 'Neu', 'Nf', 'Ng', 'P', 'Nb', 'Na', 'VC', 'COMMACATEGORY', 'Nh', 'D', 'VK', 'Nh', 'Ncd', 'VJ', 'Nc', 'PERIODCATEGORY']]
# (23, 28, 'ORG', '緯來體育台')
# (18, 22, 'DATE', '20年前')
# (0, 3, 'PERSON', '傅達仁')
