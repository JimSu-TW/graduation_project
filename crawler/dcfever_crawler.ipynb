# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from datetime import date
from bs4 import BeautifulSoup
import sys
import time
import pandas as pd
import datetime

now = datetime.datetime.now().strftime("%Y%m%d")

# %%
def listToString(s): 
    str1 = "" 
    for ele in s: 
        str1 += ele  
    return str1

# %%
#new chrome driver
def OpenChromeDriver():
    #開啟瀏覽器新分頁，下載google chrome driver
    option = webdriver.ChromeOptions()

    #fix chrome 103 problem
    option.binary_location = "/Applications/Google Chrome Beta.app/Contents/MacOS/Google Chrome Beta"

    prefs={"profile.default_content_setting_values.notifications" : 2}
    option.add_experimental_option("prefs",prefs)
    gchrome=webdriver.Chrome(options=option)
    return gchrome

def FinishedCrawler(driver):
    driver.close()

# %%
#抓取幾頁
def getPageNum(url,driver):
    driver.get(url)
            
    #Get Comment       
    soup = BeautifulSoup(driver.page_source,"html.parser")
    pages = soup.find("div", class_="article_multi_page clear")
    try:
        page_num = len(pages.find_all("a"))
    except:
        return 1
    else:
        return page_num

# %%
#抓取貼文連結
def getPostLink(url,driver):
    driver.get(url)
    
    try:
        for i in range(0,5):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
            i += 1
            time.sleep(2)
    except OSError:
        time.sleep(15)
        
        for i in range(0,5):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
            i += 1
            time.sleep(2)   
    post_link_list = []
    soup = BeautifulSoup(driver.page_source,"html.parser")
    for l in soup.find_all("div", class_="content_col"):
        temp_soup = BeautifulSoup(str(l),"html.parser")
        temp_target = temp_soup.find("a")
        temp = []
        temp.append(temp_target.get_text().strip().split('\t'))
        temp.append("https://www.dcfever.com"+temp_target["href"])
        post_link_list.append(temp)
    link_df = pd.DataFrame(data=post_link_list, columns=['Post Title', 'Link'])
    return link_df

# %%
#取得貼文日期

def getPostDate(page_soup):
    date_tag_string = page_soup.find("div", class_="article_date").get_text()
    date_tag_string = date_tag_string[date_tag_string.find("發表於")+3:date_tag_string.find("日")]
    year = date_tag_string[:date_tag_string.find("年")].strip()
    month = date_tag_string[date_tag_string.find("年")+1:date_tag_string.find("月")].strip()
    day = date_tag_string[date_tag_string.find("月")+1:].strip()
    post_date = datetime.date(int(year),int(month),int(day))
    return post_date.strftime("%Y/%m/%d")

# %%
#抓取貼文留言
def getPostContent(first_url,driver):
    
    urls=[]
    content_all=[]
    post_date = ""
    
    page_num = getPageNum(first_url,driver)
    if (page_num>1):
        for i in range(1,page_num+1):
            urls.append(first_url+"&page="+str(i))
        for url in urls:
            driver.get(url)
        #Get Comment       
            soup = BeautifulSoup(driver.page_source,"html.parser")
            if (url.find("&page=1") != -1):
                post_date = getPostDate(soup)
        
        content_all+=soup.find("div",class_="article_content").get_text(strip=True)
    
    else:
        driver.get(first_url)
        soup = BeautifulSoup(driver.page_source,"html.parser")
        post_date = getPostDate(soup)
        content_all+=soup.find("div",class_="article_content").get_text(strip=True)

    FinishedCrawler(driver)
    return listToString(content_all), post_date

# %%
# 兩部份合併
search_part = getPostLink('https://www.dcfever.com/phones/articles.php?id=2922', OpenChromeDriver())
news_part = getPostLink('https://www.dcfever.com/news/search.php?keyword=iphone13&form_action=search_action&search_btn=%E6%90%9C%E5%B0%8B', OpenChromeDriver())
# 22  https://www.dcfever.com/news/readnews.php?id=2...

# %%
# 先把爬下來的主題跟網址存起來
file_name = "crawler_data/DCfever_iphone13_Link"+now+".csv"
link_df.to_csv(file_name, index=False, encoding="utf-8")

# %%
contents = []
dates = []
for link in link_df.loc[:,"Link"]:
    temp_content, temp_date = getPostContent(link,OpenChromeDriver())
    contents.append(temp_content)
    dates.append(temp_date)

content_df = pd.DataFrame({'Content': contents,'Date': dates})

# %%
all_df = link_df.join(content_df)
all_df
# Out:
#                                           Post Title  \
# 0     [【iOS 15.4 新功能】iPhone 13 Pro 戴口罩使用 Face ID 實試]
# 1   [iPhone iOS 15.1 更新：新增 ProRes 影片及 FaceTime 同播同享]
# 2     [iPhone Leather MagSafe Wallet 試玩：點只支援「尋找」咁簡單]
# 3                           [iPhone 13 炒價直擊：今年都是開紅盤]
# 4                     [iPhone 13 系列首位用家：鍾意微距拍攝方便影食物]
# 5                  [iPhone 13 系列開箱 (連影片)：看看跟上代有什麼不同]
# 6                           [iPhone 13 系列兩個因素很大機會炒燶]
# 7                               [iPhone 13 五台出機優惠全集]
# 8        [【攝力分析】iPhone 13、iPhone 13 Pro 系列看似平淡但進步很大]
# 9                     [iPhone 13 系列炒價分析：或是消費券套現最佳工具]
# 10                     [iPhone 13 系列懶人包：一分鍾了解所有升級要點]
# 11                       [iPhone 13 發表：依然是最高性價比的一款？]
# 12                 [母親節快樂！iPhone 13 Pro 拍下無法可修飾的一對手]
# 13                 [iPhone 12 iPhone 13 爆災情：聖誕屏幕夠應節]
# 14                   [iPhone 13 mini 詳測：最強細機，使用時間合格]
# 15                [iPhone 13 系列電量曝光：最多升 20% 機身會否加厚？]
# 16                [iPhone 13 Pro 系列定價比較：512GB 以筍價開賣]
# 17                          [iPhone 13 系列定價曝光：終於要加價]
# 18        [iPhone 13 Pro 背面與 iPhone 12 Pro 對照：三鏡變大了]
# 19                          [iPhone 13 外型曝光：設計有兩大改變]
# 20                      [傳 iPhone 13 不會推出！無機用會世界未日？]
# 21                             [告別「劉海」：iPhone 13 曝光]
# 22            [最強 Apple 分析師預測 iPhone 13 與 iPhone 14]
#
#                                                  Link  \
# 0   https://www.dcfever.com/news/readnews.php?id=3...
# 1   https://www.dcfever.com/news/readnews.php?id=3...
# 2   https://www.dcfever.com/news/readnews.php?id=3...
# 3   https://www.dcfever.com/news/readnews.php?id=3...
# 4   https://www.dcfever.com/news/readnews.php?id=3...
# 5   https://www.dcfever.com/news/readnews.php?id=3...
# 6   https://www.dcfever.com/news/readnews.php?id=3...
# 7   https://www.dcfever.com/news/readnews.php?id=3...
# 8   https://www.dcfever.com/news/readnews.php?id=3...
# 9   https://www.dcfever.com/news/readnews.php?id=3...
# 10  https://www.dcfever.com/news/readnews.php?id=3...
# 11  https://www.dcfever.com/news/readnews.php?id=3...
# 12  https://www.dcfever.com/news/readnews.php?id=3...
# 13  https://www.dcfever.com/news/readnews.php?id=3...
# 14  https://www.dcfever.com/news/readnews.php?id=3...
# 15  https://www.dcfever.com/news/readnews.php?id=3...
# 16  https://www.dcfever.com/news/readnews.php?id=3...
# 17  https://www.dcfever.com/news/readnews.php?id=3...
# 18  https://www.dcfever.com/news/readnews.php?id=3...
# 19  https://www.dcfever.com/news/readnews.php?id=3...
# 20  https://www.dcfever.com/news/readnews.php?id=2...
# 21  https://www.dcfever.com/news/readnews.php?id=2...
# 22  https://www.dcfever.com/news/readnews.php?id=2...
#
#                                               Content        Date
# 0   文：TonyApple 在今日凌晨釋出 iOS 15.4 版本，加入了戴口罩使用 Face ...  2022/03/15
# 1   文：TonyApple 剛剛釋出 iOS 15.1 更新，主要迎來三大功能更新，包括 Fac...  2021/10/26
# 2   文：TonyApple 為iPhone 13系列推出不少全新配件，當中同樣支援iPhone ...  2021/10/06
# 3   文：Tony每年 iPhone 的新機推出，除新功能外，大家都想八卦一下有沒有炒價，想知新功...  2021/09/24
# 4   文：TonyiPhone 13系列今日正式推出，SmarTone 一如以往都會提早開門營業，...  2021/09/24
# 5   文：TonyiPhone 13系列今日正式推出，為大家詳細測試之前，先送上開箱文，讓大家看看...  2021/09/24
# 6   文：TonyiPhone 13 系列的炒價，除了果農關心之外，也是大家茶餘飯後的話題。想知i...  2021/09/20
# 7   文：TonyiPhone 13系列今日起正式預售，各電訊商亦推出上台或購機優惠，大家可以看看...  2021/09/17
# 8   文：TonyiPhone 13系列經已發表，iPhone 13與iPhone 13 mini...  2021/09/17
# 9   文：TonyiPhone 13 系統昨日公佈，大家除了較關心新機有什麼地方有所升級 (可看懶...  2021/09/16
# 10  文：TonyiPhone 13 系列今早已經正式公佈，本網為大家制作懶人包，讓大家一分鐘之內...  2021/09/15
# 11  文：TonyiPhone 12去年雖然是機身尺寸最平均，而且性價比亦是相同較高的 iPhon...  2021/09/15
# 12  文：Tony剛剛踏入母親節，首先同各位母親說聲母親節快樂。有本地攝影師小雲，利用 iPhon...  2022/05/08
# 13  文：TonyApple 近日在 Counterpoint Research 的報告指，在 1...  2021/12/01
# 14  Antutu 跑分在頂級之列iPhone 13 mini亦是採用 A15 Bionic So...  2021/09/28
# 15  文：Tony每年 iPhone 的規格表內，都較少提及產品記憶體與電量等資訊，不過今早 Ap...  2021/09/08
# 16  文：Tony▲圖片來源：YouTubeiPhone 13 系列早前傳出在售價上將會有所漲價，...  2021/08/30
# 17  文：TonyiPhone 自從由 iPhone 11 開始，到進入 5G 年代，即使 Mod...  2021/08/02
# 18  文：Tony有關新一代 iPhone (暫名 iPhone 13) 的外型改變，網上一直有指...  2021/04/14
# 19  文：TonyiPhone 13 早已流出不少規格，包括有機會加入屏下 Touch ID 指紋...  2021/03/20
# 20  文：Tony今年 iPhone 傳聞跟以往一樣滿天飛，既有傳聞指是推出 iPhone 12s...  2021/02/02
# 21  文：Tony由iPhone X加入 Face ID 人面識別功能開始，iPhone 就採用了...  2020/11/23
# 22  文：TonyiPhone 12 系列推出後，有關 iPhone 13 (暫名) 的傳聞亦開始...  2020/11/09

# %%
file_name = "crawler_data/DCfever_iphone13_Data"+now+".csv"
all_df.to_csv(file_name, index=False, encoding="utf-8")
